# %%
# %matplotlib inline
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
mpl.rc('figure', figsize=(12,9))
mpl.rc('font', size=20.)
mpl.rc('font', family='serif')
mpl.rc('text', usetex=True)
mpl.rc('axes', color_cycle=['k','b','g','r','yellow'])

import pyGadget

# %%
sim0 = pyGadget.sim.Simulation('stampede/vanilla')
sim1 = pyGadget.sim.Simulation('stampede/XR_sfr_1e-3')
sim2 = pyGadget.sim.Simulation('stampede/XR_sfr_1e-2')
sim3 = pyGadget.sim.Simulation('stampede/XR_sfr_1e-1')
simX = pyGadget.sim.Simulation('stampede/XR_sfr_1e-0')

halo0 = pyGadget.halo.Halo(sim0)
halo1 = pyGadget.halo.Halo(sim1)
halo2 = pyGadget.halo.Halo(sim2)
halo3 = pyGadget.halo.Halo(sim3)
haloX = pyGadget.halo.Halo(simX)

name = ['J = 0', 'J = J$_0$', 'J = 10 J$_0$', 'J = 100 J$_0$', 'J = 1000 J$_0$']

# %% [markdown]
# # Halo Evacuation

# %%
halo0.load(1900, 'radius','total_mass','Mj')
haloX.load(112, 'radius','total_mass','Mj')

fig = plt.figure(4, figsize=(9,7))
ax0 = fig.add_subplot(211)
ax1 = fig.add_subplot(212)

ax0.loglog(halo0.data[:,0], halo0.data[:,1], 'k')
ax0.loglog(halo0.data[:,0], halo0.data[:,2], 'k--')
ax0.xaxis.set_visible(False)

ax1.loglog(haloX.data[:,0], haloX.data[:,1], 'k', label='Enclosed Mass')
ax1.loglog(haloX.data[:,0], haloX.data[:,2],'k--', label='Jeans Mass')
ax1.legend(loc=4)

xmin = .1
xmax = 100
ax0.set_xlim(xmin, xmax)
ax1.set_xlim(xmin, xmax)

ymin = .3
ymax = 4e6
ax0.set_ylim(ymin,ymax)
ax1.set_ylim(ymin,ymax)

mticks = (1,10,1e2,1e3,1e4,1e5,1e6)
ax0.set_yticks(mticks)
#ax1.set_yticks(mticks)


ax0.set_ylabel('Mass [$M_{\odot}$]')
ax1.set_ylabel('Mass [$M_{\odot}$]')
ax1.set_xlabel('Radius [pc]')

ax0.text(.03,.95, r'J = 0', ha='left', va='top', size=25, transform=ax0.transAxes)
ax1.text(.03,.95, r'J = 1000 J$_{0}$', ha='left', va='top', size=25, transform=ax1.transAxes)


plt.tight_layout(w_pad=0.0,h_pad=0.0)
fig.savefig('figures/halo/blowout.png', bbox_inches='tight')

# %%
#n0, n1, n2, n3, tag = 100, 102, 202, 135, '_z26'
#n0, n1, n2, n3, tag = 615, 609, 236, 277, ''
n0, n1, n2, n3, tag = 355, 269, 201, 200, '_t0'
#n0, n1, n2, n3, tag = 665, 575, 502, 501, '_t1k'
#n0, n1, n2, n3, tag = 974, 880, 802, 800, '_t2k'
#n0, n1, n2, n3, tag = 1283, 1184, 1100, 1100, '_t3k'
#n0, n1, n2, n3, tag = 1592, 1489, 1401, 1400, '_t4k'
#n0, n1, n2, n3, tag = 1900, 1794, 1701, 1700, '_t5k'

# %% [markdown]
# # Enclosed mass versus Jeans mass

# %%
halo0.load(n0, 'radius','total_mass','Mj')
halo1.load(n1, 'radius','total_mass','Mj')
halo2.load(n2, 'radius','total_mass','Mj')
halo3.load(n3, 'radius','total_mass','Mj')

fig = plt.figure(4, figsize=(9,12))
ax0 = fig.add_subplot(411)
ax1 = fig.add_subplot(412)
ax2 = fig.add_subplot(413)
ax3 = fig.add_subplot(414)

ax0.loglog(halo0.data[:,0], halo0.data[:,1], 'k', label='Enclosed Mass')
ax0.loglog(halo0.data[:,0], halo0.data[:,2], 'k--', label='Jeans Mass')
ax0.xaxis.set_visible(False)
l = ax0.legend(loc=9, fancybox=True)
l.get_frame().set_alpha(0.)

ax1.loglog(halo1.data[:,0], halo1.data[:,1], 'k')
ax1.loglog(halo1.data[:,0], halo1.data[:,2],'k--')
ax1.xaxis.set_visible(False)

ax2.loglog(halo2.data[:,0], halo2.data[:,1], 'k')
ax2.loglog(halo2.data[:,0], halo2.data[:,2],'k--')
ax2.xaxis.set_visible(False)

ax3.loglog(halo3.data[:,0], halo3.data[:,1], 'k', label='Enclosed Mass')
ax3.loglog(halo3.data[:,0], halo3.data[:,2],'k--', label='Jeans Mass')

xmin = 1e-3
xmax = 100
ax0.set_xlim(xmin, xmax)
ax1.set_xlim(xmin, xmax)
ax2.set_xlim(xmin, xmax)
ax3.set_xlim(xmin, xmax)

ymin = 1.
ymax = 4e6
ax0.set_ylim(ymin,ymax)
ax1.set_ylim(ymin,ymax)
ax2.set_ylim(ymin,ymax)
ax3.set_ylim(ymin,ymax)

mticks = (10,1e2,1e3,1e4,1e5,1e6)
ax0.set_yticks(mticks)
ax1.set_yticks(mticks)
ax2.set_yticks(mticks)
ax3.set_yticks(mticks)

ax0.set_ylabel('Mass [$M_{\odot}$]')
ax1.set_ylabel('Mass [$M_{\odot}$]')
ax2.set_ylabel('Mass [$M_{\odot}$]')
ax3.set_ylabel('Mass [$M_{\odot}$]')

ax3.set_xlabel('Radius [pc]')

ax0.text(.03,.95, r'J = 0', ha='left', va='top', size=25, transform=ax0.transAxes)
ax1.text(.03,.95, r'J = J$_{0}$', ha='left', va='top', size=25, transform=ax1.transAxes)
ax2.text(.03,.95, r'J = 10 J$_{0}$', ha='left', va='top', size=25, transform=ax2.transAxes)
ax3.text(.03,.95, r'J = 100 J$_{0}$', ha='left', va='top', size=25, transform=ax3.transAxes)

plt.tight_layout(w_pad=0.0,h_pad=0.0)
fig.savefig('figures/halo/jeans_comparison'+tag+'.png', bbox_inches='tight')

# %% [markdown]
# ### Enclosed Total Halo Mass

# %%
x = 'radius'
y = 'total_mass'

halo0.load(n0, x, y)
halo1.load(n1, x, y)
halo2.load(n2, x, y)
halo3.load(n3, x, y)

lw = 2.5
i = 0
for halo in [halo0,halo1,halo2,halo3]:
    r = halo.data[:,0]
    m = halo.data[:,1]
    plt.loglog(r, m, label=name[i], lw=lw)
    i += 1
plt.xlim(1e-4,1e2)
#plt.ylim(1e-4,1e6)
plt.legend(loc=0)
plt.xlabel('Radius [pc]')
plt.ylabel('Enclosed Mass [$M_{\odot}$]')
plt.savefig('figures/halo/halo_mass'+tag+'.png', bbox_inches='tight')
plt.show()

# %%
print halo0.data[-2]
print halo1.data[-1]
print halo2.data[-1]
print halo3.data[-1]
# Out:
# [  7.23456141e+01   1.86813450e+05]
# [  7.23456141e+01   1.67202174e+05]
# [  7.23456141e+01   1.52526175e+05]
# [  7.23456141e+01   1.45666391e+05]

# %% [markdown]
# ### Enclosed Halo Gas Mass

# %%
x = 'radius'
y = 'total_gas'

halo0.load(n0, x, y)
halo1.load(n1, x, y)
halo2.load(n2, x, y)
halo3.load(n3, x, y)

lw = 2.5
i = 0
for halo in [halo0,halo1,halo2,halo3]:
    r = halo.data[:,0]
    m = halo.data[:,1]
    plt.loglog(r, m, label=name[i], lw=lw)
    i += 1
plt.xlim(1e-4,1e2)
#plt.ylim(1e-4,1e6)
plt.legend(loc=0)
plt.xlabel('Radius [pc]')
plt.ylabel('Enclosed Mass [$M_{\odot}$]')
plt.savefig('figures/halo/halo_gas_mass'+tag+'.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# # Halo Temperature

# %% [markdown]
# ### Average Halo Temperature

# %%
x = 'radius'
y = 'Tavg'
halo0.load(n0, x, y)
halo1.load(n1, x, y)
halo2.load(n2, x, y)
halo3.load(n3, x, y)
haloX.load(70, x, y)

lw = 2.5
i = 0
for halo in [halo0,halo1,halo2,halo3,haloX]:
    r = halo.data[:,0]
    T = halo.data[:,1]
    plt.loglog(r*206264.806, T, label=name[i], lw=lw)
    i += 1
plt.xlim(1e2,2e7)
plt.ylim(50,2e4)
plt.legend()
plt.xlabel('Radius [AU]')
plt.ylabel('Temperature [K]')
plt.savefig('figures/halo/halotemp'+tag+'.png', bbox_inches='tight')

# %% [markdown]
# ### Halo Shell Temperature

# %%
x = 'radius'
y = 'Tshell'
halo0.load(n0, x, y)
halo1.load(n1, x, y)
halo2.load(n2, x, y)
halo3.load(n3, x, y)

lw = 2.5
i = 0
for halo in [halo0,halo1,halo2,halo3]:
    r = halo.data[:,0]
    T = halo.data[:,1]
    plt.loglog(r*206264.806, T, label=name[i], lw=lw)
    i += 1
plt.legend()
plt.xlim(1e2,2e7)
plt.ylim(50,2e4)
plt.xlabel('Radius [AU]')
plt.ylabel('Temperature [K]')
plt.savefig('figures/halo/halo_shell_Temp'+tag+'.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# # Halo Surface Density

# %%
x = 'radius'
y = 'shell_gas'
halo0.load(n0, x, y)
halo1.load(n1, x, y)
halo2.load(n2, x, y)
halo3.load(n3, x, y)

lw = 2.5
i = 0
for halo in [halo0,halo1,halo2,halo3]:
    r = halo.data[:,0]
    m = halo.data[:,1]
    r2 = r * 3.08568e18
    r1 = np.concatenate((np.array([0.]),r2[:-1]))
    a = np.pi * (r2*r2 - r1*r1)
    surface_dens = m/a
    plt.loglog(r*206264.806, surface_dens, label=name[i], lw=lw)
    i += 1
plt.xlim(50,2e7)
plt.legend()
plt.xlabel('Radius [AU]')
plt.ylabel('Surface density [g cm$^{-2}$]')
plt.savefig('figures/halo/surface_density'+tag+'.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# # Spherical Accretion Rate

# %% [raw]
# x = 'radius'
# y = 'cshell'
# halo0.load(n0, x, y)
# halo1.load(n1, x, y)
# halo2.load(n2, x, y)
# halo3.load(n3, x, y)
#
# G = 6.6726e-8
# lw = 2.5
# i = 0
# for halo in [halo0,halo1,halo2,halo3]:
#     r = halo.data[:,0]
#     cs = halo.data[:,1]
#     acc = (cs**3 / G) * (3.15569e7/1.989e33)
#     plt.loglog(r*206264.806, acc, label=name[i], ls=linestyle[i], lw=lw)
#     i += 1
# plt.xlim(100,2e7)
# plt.ylim(1e-4,10)
# plt.legend()
# plt.xlabel('Radius [AU]')
# plt.ylabel('Accretion Rate [M$_{\odot}$ yr$^{-1}$]')
# plt.savefig('figures/halo/spherical_acc'+tag+'.png', bbox_inches='tight')
# plt.show()

# %% [markdown]
# # Disk Accretion Rate

# %% [raw]
# x = 'radius'
# y = 'shell_gas'
# z = 'cshell'
# halo0.load(n0, x, y, z)
# halo1.load(n1, x, y, z)
# halo2.load(n2, x, y, z)
# halo3.load(n3, x, y, z)
#
# G = 6.6726e-8
# alpha = 0.1
# lw = 2.5
# i = 0
# for halo in [halo0,halo1,halo2,halo3]:
#     r = halo.data[:,0]
#     m = halo.data[:,1]
#     cs = halo.data[:,2]
#     halo.sim.track_sinks()
#     M_sink = halo.sim.sink1.mass[-1] * 1.989e33
#
#     r2 = r * 3.08568e16
#     r1 = np.concatenate((np.array([0.]),r2[:-1]))
#     area = np.pi * (r2*r2 - r1*r1)
#     surface_dens = m/area
#     kepler_freq = np.sqrt(G * M_sink / r2**3)
#     disk_acc = 3 * np.pi * alpha * cs**2 * surface_dens / kepler_freq
#
#     plt.loglog(r*206264.806, disk_acc * (3.15569e7/1.989e33), label=name[i], lw=lw)
#     i += 1
# plt.xlim(1e2,2e7)
# plt.legend()
# plt.xlabel('Radius [AU]')
# plt.ylabel('Accretion Rate [M$_{\odot}$ yr$^{-1}$]')
# plt.savefig('figures/halo/disk_acc'+tag+'.png', bbox_inches='tight')
# plt.show()
